# %%
import pandas as pd

# %%
data=pd.read_csv("zomatocleaned.csv")

# %%
data=data.drop(['Unnamed: 0'],axis=1)

# %%
data
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 30331                         The Farm House Bar n Grill           No
# 30332                                            Bhagini           No
# 30333  Best Brews - Four Points by Sheraton Bengaluru...           No
# 30334  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 30335                       The Nest - The Den Bengaluru           No
#
#       book_table  rating  votes                    location  \
# 0            Yes     4.1    775                Banashankari
# ...

# %% [markdown]
# # Que 1: in 'Banashankari' location which dish liked most

# %%
a=data['location']=='Banashankari'
b=data[a]
b
# Out:
#        Unnamed: 0                   name online_order book_table  rating  \
# 0               0                  Jalsa          Yes        Yes     4.1
# 1               1         Spice Elephant          Yes         No     4.1
# 2               2        San Churro Cafe          Yes         No     3.8
# 3               3  Addhuri Udupi Bhojana           No         No     3.7
# 7               7                 Onesta          Yes        Yes     4.6
# ...           ...                    ...          ...        ...     ...
# 14289       23036      Kidambi's Kitchen           No         No     3.4
# 14501       23570          Stoned Monkey          Yes         No     4.3
# 14586       23931      Srikrishna Bhavan          Yes         No     3.8
# 14600       23954      The Krishna Grand          Yes         No     3.9
# 27898       51874     Sai Super Sandwich          Yes         No     3.2
#
#        votes      location            rest_type  \
# ...

# %%
b['dish_liked'].value_counts().sort_values(ascending=False)
# Out:
# Pasta, Gelato, Garlic Bread, Mojito, Nachos, Paneer Pizza, Mocktails                               8
# Pasta, Lunch Buffet, Masala Papad, Paneer Lajawab, Tomato Shorba, Dum Biryani, Sweet Corn Soup     6
# Churros, Cannelloni, Minestrone Soup, Hot Chocolate, Pink Sauce Pasta, Salsa, Veg Supreme Pizza    5
# Masala Dosa                                                                                        5
# Farmhouse Pizza, Chocolate Banana, Virgin Mojito, Pasta, Paneer Tikka, Lime Soda, Prawn Pizza      5
#                                                                                                   ..
# Vegetable Biryani, Masala Dosa, Kulcha, Masala Papad, Tomato Soup                                  1
# Garlic Bread, Pasta, Nachos, Salsa, Thin Crust Pizza                                               1
# Pasta, Lunch Buffet, Paneer Lajawab, Masala Papad, Biryani, Tomato Shorba, Dal Makhani             1
# ...

# %%
result=b['dish_liked'].value_counts().sort_values(ascending=False)
result.head(3)

#top 3 dishesh which are most liked in Banashankari
# Out:
# Pasta, Gelato, Garlic Bread, Mojito, Nachos, Paneer Pizza, Mocktails                               8
# Pasta, Lunch Buffet, Masala Papad, Paneer Lajawab, Tomato Shorba, Dum Biryani, Sweet Corn Soup     6
# Churros, Cannelloni, Minestrone Soup, Hot Chocolate, Pink Sauce Pasta, Salsa, Veg Supreme Pizza    5
# Name: dish_liked, dtype: int64

# %% [markdown]
# # QUE 2 : which hotel or cafe have highest votes and Rating

# %%
top_votes=data.sort_values(by='votes',ascending=False)

# %%
top_votes.head(1)
# Out:
#                               name online_order book_table  rating  votes  \
# 28536  Byg Brewski Brewing Company          Yes        Yes     4.9  16832
#
#             location     rest_type  \
# 28536  Sarjapur Road  Microbrewery
#
#                                               dish_liked  \
# 28536  Cocktails, Butter Chicken, Dahi Kebab, Rajma C...
#
#                                                 cuisines approx_cost type
# 28536  Continental, North Indian, Italian, South Indi...       1,600  NaN

# %% [markdown]
# # QUE  3 : Top cities with most count of Restaurants

# %%
data.groupby('location')

# %%
data.groupby('location').count().sort_values(by='name',ascending=False)
# Out:
#                        name  online_order  book_table  rating  votes  \
# location
# BTM                    2270          2270        2270    2270   2270
# Indiranagar            1577          1577        1577    1577   1577
# Whitefield             1571          1571        1571    1571   1571
# HSR                    1561          1561        1561    1561   1561
# Koramangala 5th Block  1461          1461        1461    1461   1461
# ...                     ...           ...         ...     ...    ...
# Central Bangalore         5             5           5       5      5
# Yelahanka                 4             4           4       4      4
# Rajarajeshwari Nagar      2             2           2       2      2
# Nagarbhavi                1             1           1       1      1
# Peenya                    1             1           1       1      1
#
#                        rest_type  dish_liked  cuisines  approx_cost  type
# location
# ...
